# %%
import numpy as np
import matplotlib.pyplot as plt
import timeseriesdiff as td

# %%
x = np.linspace(0.0, 6.0 * np.pi)
y0 = np.zeros_like(x)
y1 = np.sin(x)

# %%
fig, ax = plt.subplots()
ax.fill(x, y0, 'b', x, y1, 'r', alpha=0.3)
plt.show()
